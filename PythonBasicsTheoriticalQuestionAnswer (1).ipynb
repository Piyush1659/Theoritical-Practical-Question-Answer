# %%
#THEORTICAL QUESTIONS

# What is Python, and why is it popular ?

'''
>- 1. Python is easy to learn
   2. Python has an active, supportive community
   3. Python is flexible
   4. Python is well suited to data science and analytics
   5. Python is efficient, fast, and reliable
   6. Python is the academic language.

'''

# What is an interpreter in Python ?

'''
>- Interpreter in Python Convert the source code or an high level language into
intermediate code (machine level language). It is also called translator
in programming terminology.

'''

# What are pre-defined keywords in Python ?

'''
>- Keywords are reserved words in Python that have special meanings and cannot
be used as identifiers (variable names, function names, etc.).
for Examples of keywords include if, else, while, for, def, class, import, try,
except, return, True, False, None, etc.

'''

# Can keywords be used as variable names ?

'''
>- No, keywords cannot be used as variable names in Python. Keywords are reserved
words in Python that have special meanings and cannot be used as identifiers
(variable names, function names, etc.).

'''

# What is mutability in Python ?

'''
>- Mutable data types are those whose values can be changed, such as lists and
dictionaries, can be modified after creation.

'''

# Why are lists mutable, but tuples are immutable ?

'''
>- The main difference between tuples and lists is that tuples are immutable,
meaning their contents cannot be changed after creation, while lists are mutable
and can be modified.

'''

# What is the difference between “==” and “is” operators in Python ?

'''
>- In Python, "==" and "is" operators are both used for comparison but they serve
different purposes.
The "==" operator checks for equality of values which means it evaluates whether
the values of two objects are the same.
On the other hand, "is" operator checks for identity, meaning it determines
whether two variablespoint to the same object in memory.

'''

# What are logical operators in Python ?

'''
>- Python logical operators are used to combine conditional statements, allowing
you to perform operations based on multiple conditions.

'''

# What is type casting in Python ?

'''
>- Type casting, also referred to as type conversion, is the process of changing
one data type to another in Python.

'''

# What is the difference between implicit and explicit type casting ?

'''
>- The main difference between implicit and explicit type casting is that implicit
type casting is automatic, while explicit type casting is manual.

'''

# What is the purpose of conditional statements in Python ?

'''
>- Conditional statements in Python are used to execute a specific block of code
based on the truth value of a condition.

'''

# How does the elif statement work ?

'''
>- In Python, elif is short for "else if" and is used when the first if statement
isn't true, but you want to check for another condition. Meaning, if statements
pair up with elif and else statements to perform a series of checks.

'''

# What is the difference between for and while loops ?

'''
>- “for” loops are used for iterating over a sequence of elements, while “while”
loops are used for executing code until a specified condition becomes False.

'''

# Describe a scenario where a while loop is more suitable than a for loop ?

'''
>- The while loop is used when you don't know in advance how many times you want
to execute the block of code. It continues to execute as long as the
condition is true.

'''
